# %%
import cv2
import os
import numpy as np
from deepface import DeepFace
from pymongo import MongoClient
from datetime import datetime
import google.generativeai as genai
import threading
# Out:
# 2025-02-09 13:01:39.216990: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-09 13:01:39.226446: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739086299.238067   80879 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739086299.241677   80879 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-09 13:01:39.253942: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import base64
from PIL import Image
import io

# %%
genai.configure(api_key="AIzaSyBZ3icKZY_xFz3J55DV-l9lRbDR12erRnE")

# Initialize the Gemini model (adjust model if necessary)
model = genai.GenerativeModel("gemini-1.5-flash")  # Adjust model if needed

# %%
from datetime import datetime
import pytz  # Import timezone library

def get_local_timestamp():
    """Returns the current local timestamp in a readable format."""
    # local_tz = pytz.timezone("Asia/Kolkata")  # Change this to your timezone
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")  # Local time format

# %%
from pymongo import MongoClient
import datetime

# Connect to MongoDB (use your own URI if using MongoDB Atlas)
client = MongoClient("mongodb+srv://prathmesh:xS5oWxzPRh3iFdf4@child-safe.qucb1.mongodb.net/?retryWrites=true&w=majority&appName=Child-Safe")  # or MongoDB Atlas URI
db = client["live_tracking"]
collection = db["frames"]

# %%
def preprocess_frame(frame):
    """Preprocess frame for analysis."""
    return cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
import pinecone
import uuid

from pinecone import Pinecone

# Initialize Pinecone instance
pc = Pinecone(api_key="pcsk_2tE9D6_f6NSUzBvdohHk9si8tnUKX8mQC32dg89aXfqWZWZcxtZ7RKF13TEbEb2SJBoKz")

# Connect to an existing index
index_name = "128"  # Replace with your actual index name
index = pc.Index(index_name)

# %%
# import face_recognition
# import uuid
# from datetime import datetime

# def extract_faces(frame, location):
#     """
#     Extracts the 128D face embedding from a webcam frame and visualizes the detected faces.

#     Args:
#         frame (numpy array): The image frame captured from OpenCV.

#     Returns:
#         tuple: (embedding, face_location) or (None, None) if no face detected.
#     """
#     # Convert BGR to RGB
#     rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     # Detect faces
#     face_locations = face_recognition.face_locations(rgb_frame, model="cnn")

#     if not face_locations:
#         print("No faces detected.")
#         return None, None  # No face detected

#     # Visualize the detected faces by drawing rectangles around them
#     # for (top, right, bottom, left) in face_locations:
#     #     cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)

#     # Extract face embeddings (only for the first detected face)
#     face_encoding = face_recognition.face_encodings(rgb_frame, face_locations)

#     if not face_encoding:
#         print("No face encoding found.")
#         return None, None  # No encoding found

#     # Convert encoding to list for Pinecone compatibility
#     embedding_list = face_encoding[0].tolist()
    
#     # Timestamp and unique ID for storage
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     unique_id = str(uuid.uuid4())

#     # Upsert to Pinecone
#     index.upsert([
#         (unique_id, embedding_list, {"timestamp": timestamp, "location": location})
#     ])

#     # Show the image with the detected faces
#     # cv2.imshow("Detected Faces", frame)
#     # cv2.waitKey(0)
#     # cv2.destroyAllWindows()

#     return face_encoding[0], face_locations[0]  # Return first face embedding & location

# %%
import cv2
import os

# Function to preprocess frames (resize, etc.)
def preprocess_frame(frame):
    # Resize or apply any preprocessing needed to match model input
    return cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    
def extract_frames(video_path, output_folder, frame_interval=30):
    os.makedirs(output_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    saved_frames = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_folder, f"frame_{frame_count}.jpg")
            
            # Save the frame in original BGR format
            cv2.imwrite(frame_filename, frame)  
            saved_frames.append(frame_filename)

        frame_count += 1

    cap.release()
    return saved_frames

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer
# import cv2
# import base64
# from datetime import datetime

# # Load LLaMA 2 model and tokenizer
# model_name = "meta-llama/Llama-2-13b-chat-hf"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")

# def analyze_violence(frame):
#     """Send frame to LLaMA 2 for violence detection analysis."""

#     # Convert frame to Base64
#     _, buffer = cv2.imencode(".jpg", frame)
#     image_base64 = base64.b64encode(buffer).decode("utf-8")

#     # Prompt for violence detection
#     prompt = f"""
#     Analyze the following scene and answer the questions:
#     - Are there any signs of fighting, abuse, violence, or assault?
#     - What is happening in this image?
#     - What actions are being performed in the scene?
#     - Detect emotions like fear, aggression, or danger.
#     - Rate violence in percentage.
    
#     The image data is: {image_base64[:200]}... (truncated for readability)
#     """

#     inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
#     output = model.generate(**inputs, max_length=300)
#     description = tokenizer.decode(output[0], skip_special_tokens=True)

#     # Logging
#     log_filename = "violence_analysis_log.txt"
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open(log_filename, "a") as file:
#         file.write(f"\nTimestamp: {timestamp}\n")
#         file.write(f"Analysis: {description}\n")
#         file.write("=" * 30)  # Separator for readability

#     print(f"Violence analysis appended to {log_filename}")
#     return description

# %%
# import cv2
# from huggingface_hub import InferenceClient

# # Initialize Hugging Face client
# client = InferenceClient(api_key="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")  # Replace with your actual API key

# def get_frame_description(frame):
#     """
#     Takes a frame from a video, saves it as an image, and gets a description using Hugging Face API.

#     :param frame: OpenCV frame (numpy array)
#     :return: Image description as a string
#     """
#     image_path = "current_frame.jpg"

#     # Save the frame
#     cv2.imwrite(image_path, frame)

#     # Read the image as binary
#     with open(image_path, "rb") as img_file:
#         img_data = img_file.read()

#     # Make request to Hugging Face API
#     completion = client.text_generation(
#         model="meta-llama/Llama-3.2-11B-Vision-Instruct",
#         inputs={"image": img_data, "text": "Describe this image in one sentence."},
#         max_new_tokens=100  # Adjust this value based on your needs
#     )

#     # Extract and return the description
#     return completion

# # Example: Capture frame from video
# cap = cv2.VideoCapture("V_11.mp4")  # Replace with your video file path

# ret, frame = cap.read()
# if ret:
#     description = get_frame_description(frame)
#     print("Image Description:", description)

# cap.release()

# %%
# def analyze_violence(frame):
#     """Send frame to Gemini API for violence detection."""
#     _, buffer = cv2.imencode(".jpg", frame)
#     image_base64 = base64.b64encode(buffer).decode("utf-8")
    
#     prompt = """
#     Describe this image:
#     - Are there any signs of fighting, abuse, violence, or assault?
#     - What is happening in this image?
#     - What actions are being performed in the scene?
#     - Detect emotions like fear, aggression, or danger.
#     - Rate violence in  percentage.
#     """
    
#     response = model.generate_content([
#         {
#             "parts": [
#                 {"text": prompt},
#                 {"inline_data": {"mime_type": "image/jpeg", "data": image_base64}}
#             ]
#         }
#     ])
    
#     description= response.text if response else "No description available"

#     log_filename = "violence_analysis_log.txt"
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open(log_filename, "a") as file:
#         file.write(f"\nTimestamp: {timestamp}\n")
#         file.write(f"Analysis: {description}\n")
#         file.write("="*30)  # Separator for readability

#     print(f"Violence analysis appended to {log_filename}")
#     return description

# %%
import numpy as np
import cv2
import ollama
import time 

def analyze_violence(frame):
    """Analyzes violence in an image frame, either from a file path or a NumPy array."""
    
    if isinstance(frame, str):  # If `frame` is a file path, read the image
        print(f"Debug: Loading image from path: {frame}")
        frame = cv2.imread(frame)  # Convert it to a NumPy array
    
    if frame is None:
        raise ValueError("Error: Received an empty or invalid frame.")

    if not isinstance(frame, np.ndarray):
        raise TypeError(f"Error: Frame should be a numpy array, but got {type(frame)}")

    # Ensure frame is uint8 format
    if frame.dtype != np.uint8:
        frame = frame.astype(np.uint8)

    # Ensure frame has 3 color channels (BGR)
    if len(frame.shape) == 2:  # If grayscale, convert to BGR
        frame = cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)
    elif len(frame.shape) == 3 and frame.shape[2] == 4:  # If RGBA, convert to BGR
        frame = cv2.cvtColor(frame, cv2.COLOR_RGBA2BGR)

    # Convert frame to JPG format
    success, img_encoded = cv2.imencode('.jpg', frame)
    if not success:
        raise ValueError("Error: Failed to encode image.")

    img_bytes = img_encoded.tobytes()
    start_time=time.time()
    # Define the prompt
    prompt = """
      Analyze this image and classify it based on violence. Provide output in the following format:
    
     - **Violence Category:** (None, Mild, Moderate, Severe)
     - **Description:** What is happening in the image? Are there signs of fighting, abuse, or assault?
     - **Emotion Detected:** (Fear, Aggression, Panic, Neutral)
     - **Violence Score (0-100):** Provide a percentage-based rating of violence in the scene.

    
    """

    # Call the model with the image
    response = ollama.chat(
        model='llava:7b',
        messages=[{
            'role': 'user',
            'content': prompt,
            'images': [img_bytes]
        }]
    )

    elapsed_time = time.time() - start_time
    print(f"Time taken for model to respond: {elapsed_time:.2f} seconds")

    print(response['message']['content'])
    return response['message']['content']

# %%
def send_frame_to_server(frame, server_url):
    _, img_encoded = cv2.imencode('.jpg', frame)
    img_bytes = img_encoded.tobytes()
    response = requests.post(server_url, files={"file": img_bytes})
    return response.text

# %%
# # import cv2
# # import base64
# # import threading
# # from datetime import datetime
# # import numpy as np

# def analyze_violence(frame):
#     """Send frame to Gemini API for violence detection (optimized for speed)."""
    
#     # ✅ Reduce Image Size (Resizing to 224x224 for faster processing)
#     frame_resized = cv2.resize(frame, (224, 224))

#     # ✅ Convert to Base64
#     _, buffer = cv2.imencode(".jpg", frame_resized)
#     image_base64 = base64.b64encode(buffer).decode("utf-8")

#     # ✅ Optimized Prompt (Make it more direct)
#     prompt = "Detect violence or aggression in this image. Rate it in percentage (0-100)."

#     # ✅ Use Multi-threading for Faster API Calls
#     response = model.generate_content([
#         {
#             "parts": [
#                 {"text": prompt},
#                 {"inline_data": {"mime_type": "image/jpeg", "data": image_base64}}
#             ]
#         }
#     ])

#     description= response.text if response else "No description available"

#     log_filename = "violence_analysis_log.txt"
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open(log_filename, "a") as file:
#         file.write(f"\nTimestamp: {timestamp}\n")
#         file.write(f"Analysis: {description}\n")
#         file.write("="*30)  # Separator for readability

#     print(f"Violence analysis appended to {log_filename}")
#     return description

# %%
# from google.cloud import vision
# import io
# import os

# # ✅ Set Your Google Cloud Vision API Key
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "child-safety-66b48-87091fc373dc.json"

# # ✅ Initialize Google Vision Client
# client = vision.ImageAnnotatorClient()

# def analyze_violence_google(frame):
#     """Detect violence in an image using Google Cloud Vision API."""
    
#     # Convert frame to bytes
#     _, buffer = cv2.imencode(".jpg", frame)
#     image_bytes = io.BytesIO(buffer)

#     # Create image request
#     image = vision.Image(content=image_bytes.getvalue())

#     # Call Google Cloud Vision SafeSearch
#     response = client.safe_search_detection(image=image)
#     safe_search = response.safe_search_annotation

#     # Extract violence rating
#     likelihoods = ["UNKNOWN", "VERY_UNLIKELY", "UNLIKELY", "POSSIBLE", "LIKELY", "VERY_LIKELY"]
#     violence_score = likelihoods.index(safe_search.violence)

#     return f"Violence Likelihood: {likelihoods[violence_score]}"

# %%
# import re  # Import regex module
# def extract_violence_score(response_text):
#     """
#     Extracts the violence score from the model's output text.
#     If no violence is detected, returns 0.
#     """
#     response_text = response_text.replace("\xa0", " ").strip()  # Handle special characters

#     # Regex to find Violence Score
#     score_pattern = re.findall(r"Violence Score \(0-100\):\s*(\d+)", response_text)
#     # score_pattern = re.findall(r"Violence Score \(0-100\): (\d+)%", response_text)
#     print(score_pattern)
#     if score_pattern:
#         # Extract the highest detected violence score
#         violence_score = max(map(int, score_pattern))  # Convert to int and find max
#         return violence_score
#     else:
#         return 0  # No violence detected

def extract_violence_score(response_text):
    """
    Extracts the highest non-zero violence score from the model's output text.
    Ensures it works even if followed by additional text in parentheses or explanations.
    """
    # response_text = response_text.replace("\xa0", " ").strip()  # Normalize spaces

    # Improved regex: Allows optional text inside parentheses
    score_pattern = re.findall(r"-?\s*\*\*?Violence Score \(0-100\):\*\*?\s*(\d+)", response_text)
    # score_pattern = re.findall(r"(?:-?\s*\*\*?)?Violence Score \(0-100\):\s*(\d+)", response_text)
    # score_pattern = re.findall(r"(?:-?\s*\*\*?)?(?:Violence Score \(0-100\)|Violence Score):\s*(\d+)(?:%)?", response_text)

    print("Debug: Extracted Scores ->", score_pattern)  # Debugging output

    if score_pattern:
        violence_scores = list(map(int, score_pattern))  # Convert to integers
        non_zero_scores = [score for score in violence_scores if score > 0]  # Filter out zero values

        if non_zero_scores:
            return max(non_zero_scores)  # Return highest non-zero score
        else:
            return 0  # If all scores are zero, return 0
    else:
        print("Debug: No scores found in text!")  
        return 0  # Default value

# %%
import matplotlib.pyplot as plt
import numpy as np
import re


def display_violence_board(frame_number, violence_score):
    if violence_score is None:
        violence_score = 0  # Default to 0 if no violence score is found

    # Create or update the plot
    plt.figure(figsize=(5, 3))
    plt.clf()  # Clear the figure

    # Plot the frame number and violence score
    plt.bar(frame_number, violence_score, color='red')
    plt.xlabel('Frame Number')
    plt.ylabel('Violence Score (%)')
    plt.title(f'Frame {frame_number}: Violence Likelihood')

    plt.ylim(0, 100)  # Set y-axis limit for violence likelihood (0-100%)
    plt.pause(0.1)  # Pause to allow updating of the plot in real-time
    plt.show()

# %%
from datetime import datetime

# Store frame info in MongoDB
def store_frame_info(image_path, description, violence_score):

    timestamp =  datetime.now().strftime("%Y-%m-%d %H:%M:%S")  # Get local timestamp

    data = {
        "image_path": image_path,
        "description": description,
        "violence_score": violence_score,
        "timestamp": timestamp  # Add a timestamp for when the frame was analyzed
    }

    # Insert the data into the MongoDB collection
    collection.insert_one(data)

# %%
import  requests

TELEGRAM_BOT_TOKEN = "7782564515:AAEbZsL7YOeHKS8wbUCOY_SKi_XhmyVCADg"
TELEGRAM_CHAT_ID = "1799279694"

def send_telegram_alert(violence_score, description, timestamp, camera_location):
    """ Sends an alert message to Telegram when violence is detected. """
    message = (
            f"🚨 *Violence Alert!* 🚨\n"
            f"📍 *Location:* {camera_location}\n"
            f"⏰ *Time:* {timestamp}\n"
            f"⚠️ *Violence Score:* {violence_score}%\n"
            f"📖 *Details:* {description}"
        )   
    url = f"https://api.telegram.org/bot{TELEGRAM_BOT_TOKEN}/sendMessage"
    
    data = {
        "chat_id": TELEGRAM_CHAT_ID,
        "text": message,
        "parse_mode": "Markdown"
    }
    
    response = requests.post(url, json=data)
    print(f"📩 Telegram Notification Sent! Response: {response.status_code}, {response.text}")

# %%
# def process_video(video_path, output_folder="frames", frame_interval=30, output_text_file="output.txt"):
#     frames = extract_frames(video_path, output_folder, frame_interval)

#     with open(output_text_file, "w") as result_file:
#         for i, frame in enumerate(frames):
#             description = analyze_violence(frame)
#             print(description)
#             violence_score = extract_violence_score(description)  # Correct extraction
#             print(violence_score)
#             if violence_score is None:
#                 violence_score = 0  # Default to 0 if no score is found

#             # Store frame info in MongoDB
#             store_frame_info(frame, description, violence_score)

#             # Display real-time visualization
#             display_violence_board(i + 1, violence_score)

#             # Write results to a file
#             result_file.write(f"Frame: {frame}\nDescription: {description}\nViolence Score: {violence_score}%\n\n")
#             print(f"Processed Frame {i + 1}: Violence Score = {violence_score}%")

#             if violence_score >= 5:
#               camera_location = "Warehouse Entrance"  # Update with actual camera location


#               send_telegram_alert(violence_score, description, get_local_timestamp(), camera_location)

                
#     print(f"\nAnalysis completed! Results saved in {output_text_file}")

# %%
import concurrent.futures

# %%
def process_video(video_path, output_folder="frames", frame_interval=30, output_text_file="output.txt", server_urls=[]):
    frames = extract_frames(video_path, output_folder, frame_interval)
    
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = {}
        for i, frame in enumerate(frames):
            server_url = server_urls[i % len(server_urls)] if server_urls else None
            if server_url:
                futures[executor.submit(send_frame_to_server, frame, server_url)] = (i, frame)
            else:
                futures[executor.submit(analyze_violence, frame)] = (i, frame)
        
        with open(output_text_file, "w") as result_file:
            for future in concurrent.futures.as_completed(futures):
                i, frame = futures[future]
                try:
                    description = future.result()
                    print(description)
                    violence_score = extract_violence_score(description)
                    if violence_score is None:
                        violence_score = 0
                    store_frame_info(frame, description, violence_score)
                    display_violence_board(i + 1, violence_score)
                    result_file.write(f"Frame: {i + 1}\nDescription: {description}\nViolence Score: {violence_score}%\n\n")
                    print(f"Processed Frame {i + 1}: Violence Score = {violence_score}%")
                    if violence_score >= 5:
                      camera_location = "Warehouse Entrance"  # Update with actual camera location
        
        
                      send_telegram_alert(violence_score, description, get_local_timestamp(), camera_location)
                except Exception as e:
                    print(f"Error processing frame {i + 1}: {e}")

# %%
# Provide your video path and run the pipeline
# video_path = "V_336.mp4"  # Replace with your actual video file
video_path = "V_11.mp4" 
process_video(video_path)
# Out:
# Debug: Loading image from path: frames/frame_0.jpg
# Debug: Loading image from path: frames/frame_30.jpg
# Debug: Loading image from path: frames/frame_60.jpg
# Debug: Loading image from path: frames/frame_90.jpg
# Debug: Loading image from path: frames/frame_120.jpg
# Debug: Loading image from path: frames/frame_150.jpg
# Debug: Loading image from path: frames/frame_180.jpg
# Debug: Loading image from path: frames/frame_210.jpg
# Time taken for model to respond: 6.86 seconds
#  Violence Category: None
#
#      Description: The image appears to show two individuals outdoors during daylight hours. One person is standing while another one is on the ground, with their body positioned as if they are running or walking quickly. There are no obvious signs of fighting, abuse, or assault in this image; it seems like an ordinary moment captured from a video.
#
#      Emotion Detected: Neutral
#
#      Violence Score (0-100): 0
#  Violence Category: None
#
#      Description: The image appears to show two individuals outdoors during daylight hours. One person is standing while another one is on the ground, with their body positioned as if they are running or walking quickly. There are no obvious signs of fighting, abuse, or assault in this image; it seems like an ordinary moment captured from a video.
#
#      Emotion Detected: Neutral
#
#      Violence Score (0-100): 0
# Debug: Extracted Scores -> []
# Debug: No scores found in text!
# Processed Frame 3: Violence Score = 0%
# Time taken for model to respond: 15.90 seconds
#  Based on the image provided, here is the analysis:
#
#      - **Violence Category:** Mild
#      - **Description:** The image appears to be from a surveillance camera showing two individuals engaged in a physical confrontation. One person seems to be holding another by their arm and neck, which could indicate a form of restraint or self-defense rather than direct aggression. There are no clear signs of fighting, abuse, or assault, but the situation appears to involve some level of confrontation.
#      - **Emotion Detected:** Panic (perceived from the rapid motion captured in the image)
#      - **Violence Score (0-100):** 30%
#
# The violence score is relatively low as it seems more like a struggle or altercation rather than an intense attack. The context and nature of the situation are not entirely clear due to the angle and quality of the video, so the assessment is based on the visible signs in the image.
#  Based on the image provided, here is the analysis:
#
#      - **Violence Category:** Mild
#      - **Description:** The image appears to be from a surveillance camera showing two individuals engaged in a physical confrontation. One person seems to be holding another by their arm and neck, which could indicate a form of restraint or self-defense rather than direct aggression. There are no clear signs of fighting, abuse, or assault, but the situation appears to involve some level of confrontation.
#      - **Emotion Detected:** Panic (perceived from the rapid motion captured in the image)
#      - **Violence Score (0-100):** 30%
#
# The violence score is relatively low as it seems more like a struggle or altercation rather than an intense attack. The context and nature of the situation are not entirely clear due to the angle and quality of the video, so the assessment is based on the visible signs in the image.
# Debug: Extracted Scores -> ['30']
# Processed Frame 8: Violence Score = 30%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":65,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739086751,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 13:09:10\n\u26a0\ufe0f Violence Score: 30%\n\ud83d\udcd6 Details:  Based on the image provided, here is the analysis:\n\n     - Violence Category: Mild\n     - Description: The image appears to be from a surveillance camera showing two individuals engaged in a physical confrontation. One person seems to be holding another by their arm and neck, which could indicate a form of restraint or self-defense rather than direct aggression. There are no clear signs of fighting, abuse, or assault, but the situation appears to involve some level of confrontation.\n     - Emotion Detected: Panic (perceived from the rapid motion captured in the image)\n     - Violence Score (0-100): 30%\n\nThe violence score is relatively low as it seems more like a struggle or altercation rather than an intense attack. The context and nature of the situation are not entirely clear due to the angle and quality of the video, so the assessment is based on the visible signs in the image.","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 21.31 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person on the ground with another person standing over them, seemingly pushing or holding onto them. There is no visible sign of injury or physical harm that would indicate severe violence. The context suggests that this could be an altercation or some form of conflict, but the level of force being used appears to be minimal.
#      - **Emotion Detected:** Aggression
#      - **Violence Score (0-100):** 30
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person on the ground with another person standing over them, seemingly pushing or holding onto them. There is no visible sign of injury or physical harm that would indicate severe violence. The context suggests that this could be an altercation or some form of conflict, but the level of force being used appears to be minimal.
#      - **Emotion Detected:** Aggression
#      - **Violence Score (0-100):** 30
# Debug: Extracted Scores -> ['30']
# Processed Frame 2: Violence Score = 30%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":66,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739086756,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 13:09:15\n\u26a0\ufe0f Violence Score: 30%\n\ud83d\udcd6 Details:  - Violence Category: Mild\n     - Description: The image shows a person on the ground with another person standing over them, seemingly pushing or holding onto them. There is no visible sign of injury or physical harm that would indicate severe violence. The context suggests that this could be an altercation or some form of conflict, but the level of force being used appears to be minimal.\n     - Emotion Detected: Aggression\n     - Violence Score (0-100): 30","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 27.71 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person running on what appears to be a sidewalk or street. There are no clear signs of fighting, abuse, or assault in this particular frame. The person's pose and the context do not suggest any immediate violent action.
#      - **Emotion Detected:** Aggression (the individual seems to be in motion with intent)
#      - **Violence Score (0-100):** 20
#
# It's important to note that this analysis is based on a single frame and does not capture the full context or any subsequent actions in the image.
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person running on what appears to be a sidewalk or street. There are no clear signs of fighting, abuse, or assault in this particular frame. The person's pose and the context do not suggest any immediate violent action.
#      - **Emotion Detected:** Aggression (the individual seems to be in motion with intent)
#      - **Violence Score (0-100):** 20
#
# It's important to note that this analysis is based on a single frame and does not capture the full context or any subsequent actions in the image.
# Debug: Extracted Scores -> ['20']
# Processed Frame 4: Violence Score = 20%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":67,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739086762,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 13:09:21\n\u26a0\ufe0f Violence Score: 20%\n\ud83d\udcd6 Details:  - Violence Category: Mild\n     - Description: The image shows a person running on what appears to be a sidewalk or street. There are no clear signs of fighting, abuse, or assault in this particular frame. The person's pose and the context do not suggest any immediate violent action.\n     - Emotion Detected: Aggression (the individual seems to be in motion with intent)\n     - Violence Score (0-100): 20\n\nIt's important to note that this analysis is based on a single frame and does not capture the full context or any subsequent actions in the image.","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 35.19 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person lying on the ground with their legs bent at the knee, possibly after falling or being knocked down. There are no signs of intentional harm or fighting in this image. It is not clear whether the person is in distress or simply lying there due to another reason.
#      - **Emotion Detected:** Neutral (given the lack of context and no visible emotional expression)
#      - **Violence Score (0-100):** 0, as there are no indications of violence or harm being inflicted upon someone in this image. It appears to be a still from a video, possibly depicting an accident or a non-violent scene, rather than a violent one.
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person lying on the ground with their legs bent at the knee, possibly after falling or being knocked down. There are no signs of intentional harm or fighting in this image. It is not clear whether the person is in distress or simply lying there due to another reason.
#      - **Emotion Detected:** Neutral (given the lack of context and no visible emotional expression)
#      - **Violence Score (0-100):** 0, as there are no indications of violence or harm being inflicted upon someone in this image. It appears to be a still from a video, possibly depicting an accident or a non-violent scene, rather than a violent one.
# Debug: Extracted Scores -> ['0']
# Processed Frame 7: Violence Score = 0%
# Time taken for model to respond: 46.16 seconds
#  Based on the image provided, it is challenging to accurately determine the level of violence without additional context or information about the situation depicted. The blurred and low-quality nature of the image further complicates any conclusions regarding the intensity of the potential conflict or altercation.
#
# However, in general terms, we can infer that there may be some form of confrontation or aggression occurring between individuals within the frame. The presence of multiple people and what appears to be an object being thrown suggest a dynamic situation that could involve violence.
#
# Without more details or clearer visuals, it is not possible to provide a definitive categorization for the level of violence in this image.
#
#      - **Violence Category:** Unable to determine with confidence due to quality and context.
#      - **Description:** There is a scene depicting several individuals that may be involved in an altercation or confrontation. Signs of aggression or fighting can be observed, but the exact nature of the event remains uncertain.
#      - **Emotion Detected:** Aggression, with individuals potentially engaging in conflict.
#      - **Violence Score (0-100):** N/A due to insufficient information and image quality.
#  Based on the image provided, it is challenging to accurately determine the level of violence without additional context or information about the situation depicted. The blurred and low-quality nature of the image further complicates any conclusions regarding the intensity of the potential conflict or altercation.
#
# However, in general terms, we can infer that there may be some form of confrontation or aggression occurring between individuals within the frame. The presence of multiple people and what appears to be an object being thrown suggest a dynamic situation that could involve violence.
#
# Without more details or clearer visuals, it is not possible to provide a definitive categorization for the level of violence in this image.
#
#      - **Violence Category:** Unable to determine with confidence due to quality and context.
#      - **Description:** There is a scene depicting several individuals that may be involved in an altercation or confrontation. Signs of aggression or fighting can be observed, but the exact nature of the event remains uncertain.
#      - **Emotion Detected:** Aggression, with individuals potentially engaging in conflict.
#      - **Violence Score (0-100):** N/A due to insufficient information and image quality.
# Debug: Extracted Scores -> []
# Debug: No scores found in text!
# Processed Frame 5: Violence Score = 0%
# Time taken for model to respond: 55.36 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image depicts two individuals engaged in what appears to be a physical altercation. One person is being held down by another, with both appearing to be in motion and possibly involved in an argument or conflict. There are no visible signs of severe harm or the use of weapons that would indicate a higher level of violence.
#      - **Emotion Detected:** Aggression (as one individual appears to be asserting their dominance over the other)
#      - **Violence Score (0-100):** 30
#
# This score takes into account the physical contact between the individuals, but it is important to note that this score reflects only what is visually apparent in the image and does not consider any potential unseen actions or circumstances. Additionally, without more context or information about the situation, it is challenging to provide a definitive assessment of the level of violence or the emotions involved beyond what can be seen directly in the image.
#  - **Violence Category:** Mild
#      - **Description:** The image depicts two individuals engaged in what appears to be a physical altercation. One person is being held down by another, with both appearing to be in motion and possibly involved in an argument or conflict. There are no visible signs of severe harm or the use of weapons that would indicate a higher level of violence.
#      - **Emotion Detected:** Aggression (as one individual appears to be asserting their dominance over the other)
#      - **Violence Score (0-100):** 30
#
# This score takes into account the physical contact between the individuals, but it is important to note that this score reflects only what is visually apparent in the image and does not consider any potential unseen actions or circumstances. Additionally, without more context or information about the situation, it is challenging to provide a definitive assessment of the level of violence or the emotions involved beyond what can be seen directly in the image.
# Debug: Extracted Scores -> ['30']
# Processed Frame 1: Violence Score = 30%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":68,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739086790,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 13:09:49\n\u26a0\ufe0f Violence Score: 30%\n\ud83d\udcd6 Details:  - Violence Category: Mild\n     - Description: The image depicts two individuals engaged in what appears to be a physical altercation. One person is being held down by another, with both appearing to be in motion and possibly involved in an argument or conflict. There are no visible signs of severe harm or the use of weapons that would indicate a higher level of violence.\n     - Emotion Detected: Aggression (as one individual appears to be asserting their dominance over the other)\n     - Violence Score (0-100): 30\n\nThis score takes into account the physical contact between the individuals, but it is important to note that this score reflects only what is visually apparent in the image and does not consider any potential unseen actions or circumstances. Additionally, without more context or information about the situation, it is challenging to provide a definitive assessment of the level of violence or the emotions involved beyond what can be seen directly in the image.","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 59.84 seconds
#  - **Violence Category:** Severe
#      - **Description:** The image depicts an intense altercation with clear signs of physical violence. There are two people engaged in what appears to be a physical fight, which suggests a high level of aggression and confrontation.
#      - **Emotion Detected:** Aggression
#      - **Violence Score (0-100):** 95
#  - **Violence Category:** Severe
#      - **Description:** The image depicts an intense altercation with clear signs of physical violence. There are two people engaged in what appears to be a physical fight, which suggests a high level of aggression and confrontation.
#      - **Emotion Detected:** Aggression
#      - **Violence Score (0-100):** 95
# Debug: Extracted Scores -> ['95']
# Processed Frame 6: Violence Score = 95%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":69,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739086794,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 13:09:54\n\u26a0\ufe0f Violence Score: 95%\n\ud83d\udcd6 Details:  - Violence Category: Severe\n     - Description: The image depicts an intense altercation with clear signs of physical violence. There are two people engaged in what appears to be a physical fight, which suggests a high level of aggression and confrontation.\n     - Emotion Detected: Aggression\n     - Violence Score (0-100): 95","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
