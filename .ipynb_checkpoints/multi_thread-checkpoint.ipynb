# %%
import cv2
import os
import numpy as np
from deepface import DeepFace
from pymongo import MongoClient
from datetime import datetime
import google.generativeai as genai
import threading
# Out:
# 2025-02-09 08:58:35.214991: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-09 08:58:35.224735: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739071715.237075    4343 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739071715.240667    4343 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-09 08:58:35.252568: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import base64
from PIL import Image
import io

# %%
genai.configure(api_key="AIzaSyBZ3icKZY_xFz3J55DV-l9lRbDR12erRnE")

# Initialize the Gemini model (adjust model if necessary)
model = genai.GenerativeModel("gemini-1.5-flash")  # Adjust model if needed

# %%
from datetime import datetime
import pytz  # Import timezone library

def get_local_timestamp():
    """Returns the current local timestamp in a readable format."""
    # local_tz = pytz.timezone("Asia/Kolkata")  # Change this to your timezone
    return datetime.now().strftime("%Y-%m-%d %H:%M:%S")  # Local time format

# %%
from pymongo import MongoClient
import datetime

# Connect to MongoDB (use your own URI if using MongoDB Atlas)
client = MongoClient("mongodb+srv://prathmesh:xS5oWxzPRh3iFdf4@child-safe.qucb1.mongodb.net/?retryWrites=true&w=majority&appName=Child-Safe")  # or MongoDB Atlas URI
db = client["live_tracking"]
collection = db["frames"]

# %%
def preprocess_frame(frame):
    """Preprocess frame for analysis."""
    return cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
import pinecone
import uuid

from pinecone import Pinecone

# Initialize Pinecone instance
pc = Pinecone(api_key="pcsk_2tE9D6_f6NSUzBvdohHk9si8tnUKX8mQC32dg89aXfqWZWZcxtZ7RKF13TEbEb2SJBoKz")

# Connect to an existing index
index_name = "128"  # Replace with your actual index name
index = pc.Index(index_name)

# %%
# import face_recognition
# import uuid
# from datetime import datetime

# def extract_faces(frame, location):
#     """
#     Extracts the 128D face embedding from a webcam frame and visualizes the detected faces.

#     Args:
#         frame (numpy array): The image frame captured from OpenCV.

#     Returns:
#         tuple: (embedding, face_location) or (None, None) if no face detected.
#     """
#     # Convert BGR to RGB
#     rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

#     # Detect faces
#     face_locations = face_recognition.face_locations(rgb_frame, model="cnn")

#     if not face_locations:
#         print("No faces detected.")
#         return None, None  # No face detected

#     # Visualize the detected faces by drawing rectangles around them
#     # for (top, right, bottom, left) in face_locations:
#     #     cv2.rectangle(frame, (left, top), (right, bottom), (0, 255, 0), 2)

#     # Extract face embeddings (only for the first detected face)
#     face_encoding = face_recognition.face_encodings(rgb_frame, face_locations)

#     if not face_encoding:
#         print("No face encoding found.")
#         return None, None  # No encoding found

#     # Convert encoding to list for Pinecone compatibility
#     embedding_list = face_encoding[0].tolist()
    
#     # Timestamp and unique ID for storage
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     unique_id = str(uuid.uuid4())

#     # Upsert to Pinecone
#     index.upsert([
#         (unique_id, embedding_list, {"timestamp": timestamp, "location": location})
#     ])

#     # Show the image with the detected faces
#     # cv2.imshow("Detected Faces", frame)
#     # cv2.waitKey(0)
#     # cv2.destroyAllWindows()

#     return face_encoding[0], face_locations[0]  # Return first face embedding & location

# %%
import cv2
import os

# Function to preprocess frames (resize, etc.)
def preprocess_frame(frame):
    # Resize or apply any preprocessing needed to match model input
    return cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

    
def extract_frames(video_path, output_folder, frame_interval=30):
    os.makedirs(output_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    frame_count = 0
    saved_frames = []

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        if frame_count % frame_interval == 0:
            frame_filename = os.path.join(output_folder, f"frame_{frame_count}.jpg")
            
            # Save the frame in original BGR format
            cv2.imwrite(frame_filename, frame)  
            saved_frames.append(frame_filename)

        frame_count += 1

    cap.release()
    return saved_frames

# %%
# from transformers import AutoModelForCausalLM, AutoTokenizer
# import cv2
# import base64
# from datetime import datetime

# # Load LLaMA 2 model and tokenizer
# model_name = "meta-llama/Llama-2-13b-chat-hf"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")

# def analyze_violence(frame):
#     """Send frame to LLaMA 2 for violence detection analysis."""

#     # Convert frame to Base64
#     _, buffer = cv2.imencode(".jpg", frame)
#     image_base64 = base64.b64encode(buffer).decode("utf-8")

#     # Prompt for violence detection
#     prompt = f"""
#     Analyze the following scene and answer the questions:
#     - Are there any signs of fighting, abuse, violence, or assault?
#     - What is happening in this image?
#     - What actions are being performed in the scene?
#     - Detect emotions like fear, aggression, or danger.
#     - Rate violence in percentage.
    
#     The image data is: {image_base64[:200]}... (truncated for readability)
#     """

#     inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
#     output = model.generate(**inputs, max_length=300)
#     description = tokenizer.decode(output[0], skip_special_tokens=True)

#     # Logging
#     log_filename = "violence_analysis_log.txt"
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open(log_filename, "a") as file:
#         file.write(f"\nTimestamp: {timestamp}\n")
#         file.write(f"Analysis: {description}\n")
#         file.write("=" * 30)  # Separator for readability

#     print(f"Violence analysis appended to {log_filename}")
#     return description

# %%
# import cv2
# from huggingface_hub import InferenceClient

# # Initialize Hugging Face client
# client = InferenceClient(api_key="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")  # Replace with your actual API key

# def get_frame_description(frame):
#     """
#     Takes a frame from a video, saves it as an image, and gets a description using Hugging Face API.

#     :param frame: OpenCV frame (numpy array)
#     :return: Image description as a string
#     """
#     image_path = "current_frame.jpg"

#     # Save the frame
#     cv2.imwrite(image_path, frame)

#     # Read the image as binary
#     with open(image_path, "rb") as img_file:
#         img_data = img_file.read()

#     # Make request to Hugging Face API
#     completion = client.text_generation(
#         model="meta-llama/Llama-3.2-11B-Vision-Instruct",
#         inputs={"image": img_data, "text": "Describe this image in one sentence."},
#         max_new_tokens=100  # Adjust this value based on your needs
#     )

#     # Extract and return the description
#     return completion

# # Example: Capture frame from video
# cap = cv2.VideoCapture("V_11.mp4")  # Replace with your video file path

# ret, frame = cap.read()
# if ret:
#     description = get_frame_description(frame)
#     print("Image Description:", description)

# cap.release()

# %%
# def analyze_violence(frame):
#     """Send frame to Gemini API for violence detection."""
#     _, buffer = cv2.imencode(".jpg", frame)
#     image_base64 = base64.b64encode(buffer).decode("utf-8")
    
#     prompt = """
#     Describe this image:
#     - Are there any signs of fighting, abuse, violence, or assault?
#     - What is happening in this image?
#     - What actions are being performed in the scene?
#     - Detect emotions like fear, aggression, or danger.
#     - Rate violence in  percentage.
#     """
    
#     response = model.generate_content([
#         {
#             "parts": [
#                 {"text": prompt},
#                 {"inline_data": {"mime_type": "image/jpeg", "data": image_base64}}
#             ]
#         }
#     ])
    
#     description= response.text if response else "No description available"

#     log_filename = "violence_analysis_log.txt"
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open(log_filename, "a") as file:
#         file.write(f"\nTimestamp: {timestamp}\n")
#         file.write(f"Analysis: {description}\n")
#         file.write("="*30)  # Separator for readability

#     print(f"Violence analysis appended to {log_filename}")
#     return description

# %%
import numpy as np
import cv2
import ollama
import time 

def analyze_violence(frame):
    """Analyzes violence in an image frame, either from a file path or a NumPy array."""
    
    if isinstance(frame, str):  # If `frame` is a file path, read the image
        print(f"Debug: Loading image from path: {frame}")
        frame = cv2.imread(frame)  # Convert it to a NumPy array
    
    if frame is None:
        raise ValueError("Error: Received an empty or invalid frame.")

    if not isinstance(frame, np.ndarray):
        raise TypeError(f"Error: Frame should be a numpy array, but got {type(frame)}")

    # Ensure frame is uint8 format
    if frame.dtype != np.uint8:
        frame = frame.astype(np.uint8)

    # Ensure frame has 3 color channels (BGR)
    if len(frame.shape) == 2:  # If grayscale, convert to BGR
        frame = cv2.cvtColor(frame, cv2.COLOR_GRAY2BGR)
    elif len(frame.shape) == 3 and frame.shape[2] == 4:  # If RGBA, convert to BGR
        frame = cv2.cvtColor(frame, cv2.COLOR_RGBA2BGR)

    # Convert frame to JPG format
    success, img_encoded = cv2.imencode('.jpg', frame)
    if not success:
        raise ValueError("Error: Failed to encode image.")

    img_bytes = img_encoded.tobytes()
    start_time=time.time()
    # Define the prompt
    prompt = """
      Analyze this image and classify it based on violence. Provide output in the following format:
    
     - **Violence Category:** (None, Mild, Moderate, Severe)
     - **Description:** What is happening in the image? Are there signs of fighting, abuse, or assault?
     - **Emotion Detected:** (Fear, Aggression, Panic, Neutral)
     - **Violence Score (0-100):** Provide a percentage-based rating of violence in the scene.

    
    """

    # Call the model with the image
    response = ollama.chat(
        model='llava:7b',
        messages=[{
            'role': 'user',
            'content': prompt,
            'images': [img_bytes]
        }]
    )

    elapsed_time = time.time() - start_time
    print(f"Time taken for model to respond: {elapsed_time:.2f} seconds")

    print(response['message']['content'])
    return response['message']['content']

# %%
def send_frame_to_server(frame, server_url):
    _, img_encoded = cv2.imencode('.jpg', frame)
    img_bytes = img_encoded.tobytes()
    response = requests.post(server_url, files={"file": img_bytes})
    return response.text

# %%
# # import cv2
# # import base64
# # import threading
# # from datetime import datetime
# # import numpy as np

# def analyze_violence(frame):
#     """Send frame to Gemini API for violence detection (optimized for speed)."""
    
#     # ✅ Reduce Image Size (Resizing to 224x224 for faster processing)
#     frame_resized = cv2.resize(frame, (224, 224))

#     # ✅ Convert to Base64
#     _, buffer = cv2.imencode(".jpg", frame_resized)
#     image_base64 = base64.b64encode(buffer).decode("utf-8")

#     # ✅ Optimized Prompt (Make it more direct)
#     prompt = "Detect violence or aggression in this image. Rate it in percentage (0-100)."

#     # ✅ Use Multi-threading for Faster API Calls
#     response = model.generate_content([
#         {
#             "parts": [
#                 {"text": prompt},
#                 {"inline_data": {"mime_type": "image/jpeg", "data": image_base64}}
#             ]
#         }
#     ])

#     description= response.text if response else "No description available"

#     log_filename = "violence_analysis_log.txt"
#     timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#     with open(log_filename, "a") as file:
#         file.write(f"\nTimestamp: {timestamp}\n")
#         file.write(f"Analysis: {description}\n")
#         file.write("="*30)  # Separator for readability

#     print(f"Violence analysis appended to {log_filename}")
#     return description

# %%
# from google.cloud import vision
# import io
# import os

# # ✅ Set Your Google Cloud Vision API Key
# os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "child-safety-66b48-87091fc373dc.json"

# # ✅ Initialize Google Vision Client
# client = vision.ImageAnnotatorClient()

# def analyze_violence_google(frame):
#     """Detect violence in an image using Google Cloud Vision API."""
    
#     # Convert frame to bytes
#     _, buffer = cv2.imencode(".jpg", frame)
#     image_bytes = io.BytesIO(buffer)

#     # Create image request
#     image = vision.Image(content=image_bytes.getvalue())

#     # Call Google Cloud Vision SafeSearch
#     response = client.safe_search_detection(image=image)
#     safe_search = response.safe_search_annotation

#     # Extract violence rating
#     likelihoods = ["UNKNOWN", "VERY_UNLIKELY", "UNLIKELY", "POSSIBLE", "LIKELY", "VERY_LIKELY"]
#     violence_score = likelihoods.index(safe_search.violence)

#     return f"Violence Likelihood: {likelihoods[violence_score]}"

# %%
# import re  # Import regex module
# def extract_violence_score(response_text):
#     """
#     Extracts the violence score from the model's output text.
#     If no violence is detected, returns 0.
#     """
#     response_text = response_text.replace("\xa0", " ").strip()  # Handle special characters

#     # Regex to find Violence Score
#     score_pattern = re.findall(r"Violence Score \(0-100\):\s*(\d+)", response_text)
#     # score_pattern = re.findall(r"Violence Score \(0-100\): (\d+)%", response_text)
#     print(score_pattern)
#     if score_pattern:
#         # Extract the highest detected violence score
#         violence_score = max(map(int, score_pattern))  # Convert to int and find max
#         return violence_score
#     else:
#         return 0  # No violence detected

def extract_violence_score(response_text):
    """
    Extracts the highest non-zero violence score from the model's output text.
    Ensures it works even if followed by additional text in parentheses or explanations.
    """
    # response_text = response_text.replace("\xa0", " ").strip()  # Normalize spaces

    # Improved regex: Allows optional text inside parentheses
    score_pattern = re.findall(r"-?\s*\*\*?Violence Score \(0-100\):\*\*?\s*(\d+)", response_text)
    # score_pattern = re.findall(r"(?:-?\s*\*\*?)?Violence Score \(0-100\):\s*(\d+)", response_text)
    # score_pattern = re.findall(r"(?:-?\s*\*\*?)?(?:Violence Score \(0-100\)|Violence Score):\s*(\d+)(?:%)?", response_text)

    print("Debug: Extracted Scores ->", score_pattern)  # Debugging output

    if score_pattern:
        violence_scores = list(map(int, score_pattern))  # Convert to integers
        non_zero_scores = [score for score in violence_scores if score > 0]  # Filter out zero values

        if non_zero_scores:
            return max(non_zero_scores)  # Return highest non-zero score
        else:
            return 0  # If all scores are zero, return 0
    else:
        print("Debug: No scores found in text!")  
        return 0  # Default value

# %%
import matplotlib.pyplot as plt
import numpy as np
import re


def display_violence_board(frame_number, violence_score):
    if violence_score is None:
        violence_score = 0  # Default to 0 if no violence score is found

    # Create or update the plot
    plt.figure(figsize=(5, 3))
    plt.clf()  # Clear the figure

    # Plot the frame number and violence score
    plt.bar(frame_number, violence_score, color='red')
    plt.xlabel('Frame Number')
    plt.ylabel('Violence Score (%)')
    plt.title(f'Frame {frame_number}: Violence Likelihood')

    plt.ylim(0, 100)  # Set y-axis limit for violence likelihood (0-100%)
    plt.pause(0.1)  # Pause to allow updating of the plot in real-time
    plt.show()

# %%
from datetime import datetime

# Store frame info in MongoDB
def store_frame_info(image_path, description, violence_score):

    timestamp =  datetime.now().strftime("%Y-%m-%d %H:%M:%S")  # Get local timestamp

    data = {
        "image_path": image_path,
        "description": description,
        "violence_score": violence_score,
        "timestamp": timestamp  # Add a timestamp for when the frame was analyzed
    }

    # Insert the data into the MongoDB collection
    collection.insert_one(data)

# %%
import  requests

TELEGRAM_BOT_TOKEN = "7782564515:AAEbZsL7YOeHKS8wbUCOY_SKi_XhmyVCADg"
TELEGRAM_CHAT_ID = "1799279694"

def send_telegram_alert(violence_score, description, timestamp, camera_location):
    """ Sends an alert message to Telegram when violence is detected. """
    message = (
            f"🚨 *Violence Alert!* 🚨\n"
            f"📍 *Location:* {camera_location}\n"
            f"⏰ *Time:* {timestamp}\n"
            f"⚠️ *Violence Score:* {violence_score}%\n"
            f"📖 *Details:* {description}"
        )   
    url = f"https://api.telegram.org/bot{TELEGRAM_BOT_TOKEN}/sendMessage"
    
    data = {
        "chat_id": TELEGRAM_CHAT_ID,
        "text": message,
        "parse_mode": "Markdown"
    }
    
    response = requests.post(url, json=data)
    print(f"📩 Telegram Notification Sent! Response: {response.status_code}, {response.text}")

# %%
# def process_video(video_path, output_folder="frames", frame_interval=30, output_text_file="output.txt"):
#     frames = extract_frames(video_path, output_folder, frame_interval)

#     with open(output_text_file, "w") as result_file:
#         for i, frame in enumerate(frames):
#             description = analyze_violence(frame)
#             print(description)
#             violence_score = extract_violence_score(description)  # Correct extraction
#             print(violence_score)
#             if violence_score is None:
#                 violence_score = 0  # Default to 0 if no score is found

#             # Store frame info in MongoDB
#             store_frame_info(frame, description, violence_score)

#             # Display real-time visualization
#             display_violence_board(i + 1, violence_score)

#             # Write results to a file
#             result_file.write(f"Frame: {frame}\nDescription: {description}\nViolence Score: {violence_score}%\n\n")
#             print(f"Processed Frame {i + 1}: Violence Score = {violence_score}%")

#             if violence_score >= 5:
#               camera_location = "Warehouse Entrance"  # Update with actual camera location


#               send_telegram_alert(violence_score, description, get_local_timestamp(), camera_location)

                
#     print(f"\nAnalysis completed! Results saved in {output_text_file}")

# %%
import concurrent.futures

# %%
def process_video(video_path, output_folder="frames", frame_interval=30, output_text_file="output.txt", server_urls=[]):
    frames = extract_frames(video_path, output_folder, frame_interval)
    
    with concurrent.futures.ThreadPoolExecutor() as executor:
        futures = {}
        for i, frame in enumerate(frames):
            server_url = server_urls[i % len(server_urls)] if server_urls else None
            if server_url:
                futures[executor.submit(send_frame_to_server, frame, server_url)] = (i, frame)
            else:
                futures[executor.submit(analyze_violence, frame)] = (i, frame)
        
        with open(output_text_file, "w") as result_file:
            for future in concurrent.futures.as_completed(futures):
                i, frame = futures[future]
                try:
                    description = future.result()
                    print(description)
                    violence_score = extract_violence_score(description)
                    if violence_score is None:
                        violence_score = 0
                    store_frame_info(frame, description, violence_score)
                    display_violence_board(i + 1, violence_score)
                    result_file.write(f"Frame: {i + 1}\nDescription: {description}\nViolence Score: {violence_score}%\n\n")
                    print(f"Processed Frame {i + 1}: Violence Score = {violence_score}%")
                    if violence_score >= 5:
                      camera_location = "Warehouse Entrance"  # Update with actual camera location
        
        
                      send_telegram_alert(violence_score, description, get_local_timestamp(), camera_location)
                except Exception as e:
                    print(f"Error processing frame {i + 1}: {e}")

# %%
# Provide your video path and run the pipeline
# video_path = "V_336.mp4"  # Replace with your actual video file
video_path = "V_11.mp4" 
process_video(video_path)
# Out:
# Debug: Loading image from path: frames/frame_0.jpg
# Debug: Loading image from path: frames/frame_30.jpg
# Debug: Loading image from path: frames/frame_60.jpg
# Debug: Loading image from path: frames/frame_90.jpg
# Debug: Loading image from path: frames/frame_120.jpg
# Debug: Loading image from path: frames/frame_150.jpg
# Debug: Loading image from path: frames/frame_180.jpg
# Debug: Loading image from path: frames/frame_210.jpg
# Time taken for model to respond: 16.79 seconds
#  - **Violence Category:** Mild
#      - **Description:** In the image, there are two individuals who appear to be engaged in a physical altercation or confrontation. The person on the ground is being held by the other individual, suggesting an aggressive action or forceful restraint. There is no visible evidence of abuse or assault beyond this interaction, and there are no clear signs of fear or panic from the people involved.
#      - **Emotion Detected:** Aggression
#      - **Violence Score (0-100):** Based on the level of physical contact between the individuals and the fact that one person is holding the other, I would estimate the violence score to be around 35. The interaction seems to involve more than a casual push or shove, but it does not rise to a level of extreme aggression or severe injury that would require a higher score.
#  - **Violence Category:** Mild
#      - **Description:** In the image, there are two individuals who appear to be engaged in a physical altercation or confrontation. The person on the ground is being held by the other individual, suggesting an aggressive action or forceful restraint. There is no visible evidence of abuse or assault beyond this interaction, and there are no clear signs of fear or panic from the people involved.
#      - **Emotion Detected:** Aggression
#      - **Violence Score (0-100):** Based on the level of physical contact between the individuals and the fact that one person is holding the other, I would estimate the violence score to be around 35. The interaction seems to involve more than a casual push or shove, but it does not rise to a level of extreme aggression or severe injury that would require a higher score.
# Debug: Extracted Scores -> []
# Debug: No scores found in text!
# Processed Frame 1: Violence Score = 0%
# Time taken for model to respond: 30.10 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image shows a split screen with two videos. On the left, there is a person seemingly engaged in some form of physical activity or struggle on a street or sidewalk. The individual is captured mid-motion and it's unclear whether they are fighting, playing, or involved in any sort of abuse. The right side shows what appears to be a still image with no overt signs of violence.
#      - **Emotion Detected:** Neutral
#      - **Violence Score (0-100):** 20
#
# The context provided by the term "Fear" or "Panic" in the emotion detected would need more information, such as facial expressions or posture, to accurately assess. The image does not provide enough detail to confidently determine a specific emotion or violence score above 20, which indicates that there might be some sort of confrontation or altercation happening but it is difficult to gauge the severity from this angle and without additional context.
#  - **Violence Category:** Mild
#      - **Description:** The image shows a split screen with two videos. On the left, there is a person seemingly engaged in some form of physical activity or struggle on a street or sidewalk. The individual is captured mid-motion and it's unclear whether they are fighting, playing, or involved in any sort of abuse. The right side shows what appears to be a still image with no overt signs of violence.
#      - **Emotion Detected:** Neutral
#      - **Violence Score (0-100):** 20
#
# The context provided by the term "Fear" or "Panic" in the emotion detected would need more information, such as facial expressions or posture, to accurately assess. The image does not provide enough detail to confidently determine a specific emotion or violence score above 20, which indicates that there might be some sort of confrontation or altercation happening but it is difficult to gauge the severity from this angle and without additional context.
# Debug: Extracted Scores -> ['20']
# Processed Frame 8: Violence Score = 20%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":60,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739071756,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 08:59:15\n\u26a0\ufe0f Violence Score: 20%\n\ud83d\udcd6 Details:  - Violence Category: Mild\n     - Description: The image shows a split screen with two videos. On the left, there is a person seemingly engaged in some form of physical activity or struggle on a street or sidewalk. The individual is captured mid-motion and it's unclear whether they are fighting, playing, or involved in any sort of abuse. The right side shows what appears to be a still image with no overt signs of violence.\n     - Emotion Detected: Neutral\n     - Violence Score (0-100): 20\n\nThe context provided by the term \"Fear\" or \"Panic\" in the emotion detected would need more information, such as facial expressions or posture, to accurately assess. The image does not provide enough detail to confidently determine a specific emotion or violence score above 20, which indicates that there might be some sort of confrontation or altercation happening but it is difficult to gauge the severity from this angle and without additional context.","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 42.19 seconds
#  Based on the image provided, here's an analysis:
#
#      - **Violence Category:** None
#      - **Description:** The image shows a man running away from a group of people outside. He appears to be in a state of distress or urgency rather than engaged in a fight or abuse. There are no visible signs of physical violence within the frame, such as punching, kicking, or being restrained by others.
#      - **Emotion Detected:** Aggression (as indicated by the man's posture and direction of movement)
#      - **Violence Score (0-100):** 0 (since there is no direct evidence of violence in this image)
#
# The scene captures a moment of conflict or confrontation, but the level of violence suggested here is low. The man's actions suggest he might be fleeing from an argument or altercation rather than experiencing physical abuse or attack.
#  Based on the image provided, here's an analysis:
#
#      - **Violence Category:** None
#      - **Description:** The image shows a man running away from a group of people outside. He appears to be in a state of distress or urgency rather than engaged in a fight or abuse. There are no visible signs of physical violence within the frame, such as punching, kicking, or being restrained by others.
#      - **Emotion Detected:** Aggression (as indicated by the man's posture and direction of movement)
#      - **Violence Score (0-100):** 0 (since there is no direct evidence of violence in this image)
#
# The scene captures a moment of conflict or confrontation, but the level of violence suggested here is low. The man's actions suggest he might be fleeing from an argument or altercation rather than experiencing physical abuse or attack.
# Debug: Extracted Scores -> ['0']
# Processed Frame 4: Violence Score = 0%
# Time taken for model to respond: 50.10 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image shows an individual on the ground, being held down by another person who is standing over them with their hands on the first person's back or body. This action could be interpreted as a restraint technique, possibly in response to an incident that has just occurred or during an arrest process. There are no visible signs of fighting, abuse, or assault in this image.
#      - **Emotion Detected:** Neutral
#      - **Violence Score (0-100):** 35
#  - **Violence Category:** Mild
#      - **Description:** The image shows an individual on the ground, being held down by another person who is standing over them with their hands on the first person's back or body. This action could be interpreted as a restraint technique, possibly in response to an incident that has just occurred or during an arrest process. There are no visible signs of fighting, abuse, or assault in this image.
#      - **Emotion Detected:** Neutral
#      - **Violence Score (0-100):** 35
# Debug: Extracted Scores -> ['35']
# Processed Frame 7: Violence Score = 35%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":61,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739071776,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 08:59:35\n\u26a0\ufe0f Violence Score: 35%\n\ud83d\udcd6 Details:  - Violence Category: Mild\n     - Description: The image shows an individual on the ground, being held down by another person who is standing over them with their hands on the first person's back or body. This action could be interpreted as a restraint technique, possibly in response to an incident that has just occurred or during an arrest process. There are no visible signs of fighting, abuse, or assault in this image.\n     - Emotion Detected: Neutral\n     - Violence Score (0-100): 35","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 64.26 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person standing outside on a sidewalk, holding what appears to be a bottle or container that could potentially contain a liquid or substance. There is no immediate visible evidence of physical harm or aggression towards the individual shown. However, there are blurred elements suggesting a fast-moving action, which might indicate a possible struggle or altercation.
#      - **Emotion Detected:** Panic or Aggression
#      - **Violence Score (0-100):** Based on the image's content, with no clear signs of immediate harm or physical contact, a violence score would be difficult to assess accurately. However, considering the context and the actions of the person, I can infer that the individual might be in distress or a tense situation, which could contribute to a higher score if we were to rate the overall potential for violence within the scene.
#
# It's important to note that without more information or a clearer image, this assessment is based solely on the visual content provided and may not capture the full context of what is happening.
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person standing outside on a sidewalk, holding what appears to be a bottle or container that could potentially contain a liquid or substance. There is no immediate visible evidence of physical harm or aggression towards the individual shown. However, there are blurred elements suggesting a fast-moving action, which might indicate a possible struggle or altercation.
#      - **Emotion Detected:** Panic or Aggression
#      - **Violence Score (0-100):** Based on the image's content, with no clear signs of immediate harm or physical contact, a violence score would be difficult to assess accurately. However, considering the context and the actions of the person, I can infer that the individual might be in distress or a tense situation, which could contribute to a higher score if we were to rate the overall potential for violence within the scene.
#
# It's important to note that without more information or a clearer image, this assessment is based solely on the visual content provided and may not capture the full context of what is happening.
# Debug: Extracted Scores -> []
# Debug: No scores found in text!
# Processed Frame 5: Violence Score = 0%
# Time taken for model to respond: 71.10 seconds
#  - **Violence Category:** Mild
#      - **Description:** In the image, there is one person lying on the ground while another person appears to be reaching towards them. There are no visible signs of injury or conflict, such as raised fists or aggressive body language. The scene seems more like an altercation rather than an intense fight.
#      - **Emotion Detected:** Neutral
#      - **Violence Score (0-100):** 20
#  - **Violence Category:** Mild
#      - **Description:** In the image, there is one person lying on the ground while another person appears to be reaching towards them. There are no visible signs of injury or conflict, such as raised fists or aggressive body language. The scene seems more like an altercation rather than an intense fight.
#      - **Emotion Detected:** Neutral
#      - **Violence Score (0-100):** 20
# Debug: Extracted Scores -> ['20']
# Processed Frame 6: Violence Score = 20%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":62,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739071797,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 08:59:56\n\u26a0\ufe0f Violence Score: 20%\n\ud83d\udcd6 Details:  - Violence Category: Mild\n     - Description: In the image, there is one person lying on the ground while another person appears to be reaching towards them. There are no visible signs of injury or conflict, such as raised fists or aggressive body language. The scene seems more like an altercation rather than an intense fight.\n     - Emotion Detected: Neutral\n     - Violence Score (0-100): 20","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 81.21 seconds
#  Based on the image provided, here's my analysis:
#
#     - **Violence Category:** Mild
#     - **Description:** The image shows a person running away from another individual who appears to be chasing them. It is not clear if any physical contact has occurred, but there is a sense of urgency and perhaps fear or panic in the person's posture as they run.
#     - **Emotion Detected:** Aggression (from the chaser) and possibly Panic or Fear (from the runner)
#     - **Violence Score (0-100):** 30 (Based on the immediate actions captured, there is a potential for violence if contact were to occur. The score reflects this possibility without indicating actual violence.)
#  Based on the image provided, here's my analysis:
#
#     - **Violence Category:** Mild
#     - **Description:** The image shows a person running away from another individual who appears to be chasing them. It is not clear if any physical contact has occurred, but there is a sense of urgency and perhaps fear or panic in the person's posture as they run.
#     - **Emotion Detected:** Aggression (from the chaser) and possibly Panic or Fear (from the runner)
#     - **Violence Score (0-100):** 30 (Based on the immediate actions captured, there is a potential for violence if contact were to occur. The score reflects this possibility without indicating actual violence.)
# Debug: Extracted Scores -> ['30']
# Processed Frame 3: Violence Score = 30%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":63,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739071807,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 09:00:06\n\u26a0\ufe0f Violence Score: 30%\n\ud83d\udcd6 Details:  Based on the image provided, here's my analysis:\n\n    - Violence Category: Mild\n    - Description: The image shows a person running away from another individual who appears to be chasing them. It is not clear if any physical contact has occurred, but there is a sense of urgency and perhaps fear or panic in the person's posture as they run.\n    - Emotion Detected: Aggression (from the chaser) and possibly Panic or Fear (from the runner)\n    - Violence Score (0-100): 30 (Based on the immediate actions captured, there is a potential for violence if contact were to occur. The score reflects this possibility without indicating actual violence.)","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
# Time taken for model to respond: 92.66 seconds
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person performing a karate kick, which may be perceived as a form of self-defense or martial arts demonstration rather than violence intended to harm another individual. There are no clear signs of fighting, abuse, or assault.
#      - **Emotion Detected:** Aggression (as the person is actively participating in the physical activity and might be focused on delivering the kick)
#      - **Violence Score (0-100):** 25
#
# This score suggests that while there is a physical action being performed, it does not involve significant force or intent to harm another person. It could be interpreted as an aggressive stance for a martial arts demonstration, rather than actual violence. The context of the image and the individuals involved would play a crucial role in interpreting the situation accurately.
#  - **Violence Category:** Mild
#      - **Description:** The image shows a person performing a karate kick, which may be perceived as a form of self-defense or martial arts demonstration rather than violence intended to harm another individual. There are no clear signs of fighting, abuse, or assault.
#      - **Emotion Detected:** Aggression (as the person is actively participating in the physical activity and might be focused on delivering the kick)
#      - **Violence Score (0-100):** 25
#
# This score suggests that while there is a physical action being performed, it does not involve significant force or intent to harm another person. It could be interpreted as an aggressive stance for a martial arts demonstration, rather than actual violence. The context of the image and the individuals involved would play a crucial role in interpreting the situation accurately.
# Debug: Extracted Scores -> ['25']
# Processed Frame 2: Violence Score = 25%
# 📩 Telegram Notification Sent! Response: 200, {"ok":true,"result":{"message_id":64,"from":{"id":7782564515,"is_bot":true,"first_name":"Violence detector","username":"ViolencePredictionBot"},"chat":{"id":1799279694,"first_name":"Prathmesh","last_name":"Atkale","type":"private"},"date":1739071819,"text":"\ud83d\udea8 Violence Alert! \ud83d\udea8\n\ud83d\udccd Location: Warehouse Entrance\n\u23f0 Time: 2025-02-09 09:00:18\n\u26a0\ufe0f Violence Score: 25%\n\ud83d\udcd6 Details:  - Violence Category: Mild\n     - Description: The image shows a person performing a karate kick, which may be perceived as a form of self-defense or martial arts demonstration rather than violence intended to harm another individual. There are no clear signs of fighting, abuse, or assault.\n     - Emotion Detected: Aggression (as the person is actively participating in the physical activity and might be focused on delivering the kick)\n     - Violence Score (0-100): 25\n\nThis score suggests that while there is a physical action being performed, it does not involve significant force or intent to harm another person. It could be interpreted as an aggressive stance for a martial arts demonstration, rather than actual violence. The context of the image and the individuals involved would play a crucial role in interpreting the situation accurately.","entities":[{"offset":3,"length":15,"type":"bold"},{"offset":25,"length":9,"type":"bold"},{"offset":56,"length":5,"type":"bold"},{"offset":85,"length":15,"type":"bold"},{"offset":108,"length":8,"type":"bold"}]}}
